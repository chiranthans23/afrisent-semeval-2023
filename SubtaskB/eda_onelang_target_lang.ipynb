# %%
import pandas as pd

languages = ['am', 'dz', 'ha', 'ig', 'kr', 'ma', 'pcm', 'pt', 'sw', 'ts', 'twi', 'yo']
data = []



for language in languages:
    df = pd.read_csv(f"../SubtaskA/train/{language}_train.tsv", sep='\t', names=['text', 'label'], header=0)
    print(f"length of {language} data: {len(df)}")
    data.append(len(df))
# Out:
# length of am data: 5984
# length of dz data: 1651
# length of ha data: 14172
# length of ig data: 10192
# length of kr data: 3302
# length of ma data: 5583
# length of pcm data: 5121
# length of pt data: 3063
# length of sw data: 1810
# length of ts data: 804
# length of twi data: 3481
# length of yo data: 8522

# %%
import matplotlib.pyplot as plt

plt.plot(languages, data)
plt.show()

# %%
def get_class_dist(y):
    class_count = {lang: 0 for lang in languages}
    for l in y:
        class_count[l] += 1
    return class_count
